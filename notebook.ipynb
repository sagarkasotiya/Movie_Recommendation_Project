# %%
import pandas as pd
credits=pd.read_csv(r'data\tmdb_5000_credits.csv')
movies=pd.read_csv(r'data\tmdb_5000_movies.csv')

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#merging both datasets
movies=movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.drop(['budget','homepage','original_language','original_title','popularity','production_companies','production_countries','release_date','revenue','runtime',
             'spoken_languages','status','tagline','vote_average','vote_count','id'],inplace=True,axis=1)

# %%
movies.head()
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# ...

# %%
movies.isnull().sum()
# Out:
# genres      0
# keywords    0
# overview    3
# title       0
# movie_id    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# genres      0
# keywords    0
# overview    0
# title       0
# movie_id    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.head(2)
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# ...

# %%
movies['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# we have to convert genres in this format ['Action','Adventure','SciFi']

# %%
import ast
def genre_convert(obj):
    m=ast.literal_eval(obj)
    list=[]
    for i in m:
        list.append(i['name'])
    return list

# %%
movies['genres']=movies['genres'].apply(genre_convert)

# %%
movies.head(2)
# Out:
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# ...

# %%
movies['keywords']=movies['keywords'].apply(genre_convert)
movies['overview']=movies['overview'].apply(lambda x:x.split())

# %%
movies.head(1)
# Out:
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview   title  movie_id  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  Avatar     19995
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies['cast'][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
def cast_convert(obj):
    m=ast.literal_eval(obj)
    list=[]
    count=0
    for i in m:
        if count!=5:
            list.append(i['name'])
            count=count+1
            
        else:
            break
    return list

# %%
movies['cast']=movies['cast'].apply(cast_convert)

# %%
movies.head(1)
# Out:
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview   title  movie_id  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  Avatar     19995
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies['crew'][0]
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
import numpy as np
def fetch_director(obj):
    
    m=ast.literal_eval(obj)
    list=[]
    for i in m:
        if i['job']=='Director':
            list.append(i['name'])
    return list

# %%
movies['crew']=movies['crew'].apply(fetch_director)

# %%
movies.head(2)
# Out:
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
#
#                                                 cast              crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...   [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...  [Gore Verbinski]

# %%
movies.isnull().sum()
# Out:
# genres      0
# keywords    0
# overview    0
# title       0
# movie_id    0
# cast        0
# crew        0
# dtype: int64

# %%
def space_remove(obj):
    for i in range(len(obj)):
        obj[i] = obj[i].replace(' ', '')
    return obj

# %%
movies['keywords']=movies['keywords'].apply(space_remove)
movies['cast']=movies['cast'].apply(space_remove)
movies['crew']=movies['crew'].apply(space_remove)
movies['genres']=movies['genres'].apply(space_remove)

# %%
movies.head()
# Out:
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
# ...

# %%
movies['tags']=movies['genres']+movies['keywords']+movies['cast']+movies['crew']+movies['overview']

# %%
movies.drop(['genres','keywords','cast','crew','overview'],axis=1,inplace=True)

# %%
movies.head()
# Out:
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
# 2                                   Spectre    206647
# 3                     The Dark Knight Rises     49026
# 4                               John Carter     49529
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4  [Action, Adventure, ScienceFiction, basedonnov...

# %%
movies['tags']=movies['tags'].apply(lambda x:" ".join(i for i in x))

# %%
movies.head()
# Out:
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
# 2                                   Spectre    206647
# 3                     The Dark Knight Rises     49026
# 4                               John Carter     49529
#
#                                                 tags
# 0  Action Adventure Fantasy ScienceFiction cultur...
# 1  Adventure Fantasy Action ocean drugabuse exoti...
# 2  Action Adventure Crime spy basedonnovel secret...
# 3  Action Crime Drama Thriller dccomics crimefigh...
# 4  Action Adventure ScienceFiction basedonnovel m...

# %%
movies['tags'][0]
# Out:
# 'Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver StephenLang MichelleRodriguez JamesCameron In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
#text preprocessing

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

def text_preprocessing(txt):
    #text to lower case
    txt=txt.lower()
    
    #removing punctuation
    translator=str.maketrans("","",string.punctuation)
    txt=txt.translate(translator)
    
    #remove digits
    txt="".join([word for word in txt if not word.isdigit()])
    
    #text without whitespace
    # txt=" ".join(txt.split())
    
    #txt normalization
    # txt=str(TextBlob(txt).correct())
    
    
    #word tokenize
    txt=word_tokenize(txt) #list

    #stop words removal
    stop_words=set(stopwords.words('english'))
    filtered_txt=[word for word in txt if word not in stop_words]
    
    #stemming
    stemmer=PorterStemmer()
    txt=[stemmer.stem(word) for word in filtered_txt]
    
    #lemmatization
    lemmatizer=WordNetLemmatizer()
    txt=[lemmatizer.lemmatize(word) for word in txt]
    
    return txt

# %%
import swifter
movies['tags']=movies['tags'].swifter.apply(text_preprocessing)
movies.head()
# Out:
# Pandas Apply:   0%|          | 0/4806 [00:00<?, ?it/s]
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
# 2                                   Spectre    206647
# 3                     The Dark Knight Rises     49026
# 4                               John Carter     49529
#
#                                                 tags
# 0  [action, adventur, fantasi, sciencefict, cultu...
# 1  [adventur, fantasi, action, ocean, drugabus, e...
# 2  [action, adventur, crime, spi, basedonnovel, s...
# 3  [action, crime, drama, thriller, dccomic, crim...
# 4  [action, adventur, sciencefict, basedonnovel, ...

# %%
movies['tags']=movies['tags'].apply(lambda x: " ".join(word for word in x))
movies.head()
# Out:
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
# 2                                   Spectre    206647
# 3                     The Dark Knight Rises     49026
# 4                               John Carter     49529
#
#                                                 tags
# 0  action adventur fantasi sciencefict culturecla...
# 1  adventur fantasi action ocean drugabus exotici...
# 2  action adventur crime spi basedonnovel secreta...
# 3  action crime drama thriller dccomic crimefight...
# 4  action adventur sciencefict basedonnovel mar m...

# %%
#vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer=TfidfVectorizer(max_features=5000)
vectors=vectorizer.fit_transform(movies['tags'])
vectorizer.get_feature_names_out()
# Out:
# array(['aaron', 'aaroneckhart', 'aarontaylorjohnson', ..., 'zone', 'zoo',
#        'zooeydeschanel'], dtype=object)

# %%
vectors.shape
# Out:
# (4806, 5000)

# %%
import pickle
pickle.dump(vectors,open('vectors.pkl','wb'))

# %%
movies.head()
# Out:
#                                       title  movie_id  \
# 0                                    Avatar     19995
# 1  Pirates of the Caribbean: At World's End       285
# 2                                   Spectre    206647
# 3                     The Dark Knight Rises     49026
# 4                               John Carter     49529
#
#                                                 tags
# 0  action adventur fantasi sciencefict culturecla...
# 1  adventur fantasi action ocean drugabus exotici...
# 2  action adventur crime spi basedonnovel secreta...
# 3  action crime drama thriller dccomic crimefight...
# 4  action adventur sciencefict basedonnovel mar m...

# %%
import pickle
movies_with_id={'title':movies['title'],
        'movie_id':movies['movie_id']}
pickle.dump(movies_with_id,open('movies_with_id.pkl','wb'))

# %%
#cosine distance
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
l=sorted(list(enumerate([float(dist) for dist in list(similarity[0])])),reverse=True,key=lambda x:x[1])
l
# Out:
# [(0, 1.0000000000000004),
#  (2405, 0.23204131884951745),
#  (3606, 0.16763876890886345),
#  (778, 0.160536491522253),
#  (260, 0.15167623532509428),
#  (1916, 0.15013641756281312),
#  (47, 0.14682580334805137),
#  (539, 0.14590787706422062),
#  (942, 0.14346498639400088),
#  (2936, 0.13899108997994053),
#  (507, 0.1385519925713491),
#  (582, 0.13821755286698298),
#  (1214, 0.13742670017574435),
#  (3536, 0.13653378332008717),
#  (3728, 0.13587151261585714),
#  (438, 0.13392506688101524),
#  (2782, 0.13292582898789063),
#  (1342, 0.1323954265193172),
#  (83, 0.12950900553154793),
#  (1087, 0.12905098734498444),
#  (311, 0.12851735615914336),
#  (2280, 0.12776549082221583),
#  (2200, 0.1249532689667109),
#  (300, 0.12450232913507411),
#  (4336, 0.1242634039469616),
#  (74, 0.12421995216606499),
#  (4046, 0.12320277344019409),
#  (513, 0.12243152641998312),
#  (1346, 0.12225108354099049),
#  (2969, 0.11802496794464526),
#  (4190, 0.1177459630201117),
#  (1827, 0.11695655462540969),
# ...

# %%
def recommend(movie):
    movie_index=int(movies[movies['title']==movie].index[0])
    l=sorted(list(enumerate([float(dist) for dist in list(similarity[movie_index])])),reverse=True,key=lambda x:x[1])
    movie_indices=[]
    for touple in l[0:5]:
        movie_indices.append(touple[0])
    movies_id=[]
    for index in movie_indices:
        movies_id.append(movies['movie_id'][index])
    
    id=[int(id) for id in movies_id]
    return id

# %%
recommend('Batman')
# Out:
# [268, 2661, 415, 364, 49026]
